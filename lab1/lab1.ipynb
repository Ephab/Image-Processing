# %%
import cv2
img = cv2.imread('images/cameraman.tif', cv2.IMREAD_GRAYSCALE) #Load the image data into a NumPy array

# %%
import cv2
import matplotlib.pyplot as plt

plt.imshow(img, cmap='gray')
plt.show()

# %%
from PIL import Image
import matplotlib.cm as cm

img2 = Image.open('images/lena_gray_256.tif')
plt.imshow(img2, cmap=cm.Greys_r)
plt.show()

# %%
cv2.imwrite('output/new_image.jpg', img);

# %%
img2.save('output/new_image2.jpg')

# %%
print(img.shape)
# Out:
# (512, 512)

# %%
print(img)
# Out:
# [[200 200 200 ... 189 190 190]
#  [200 199 199 ... 190 190 190]
#  [199 199 199 ... 190 190 190]
#  ...
#  [ 25  25  27 ... 139 122 147]
#  [ 25  25  26 ... 158 141 168]
#  [ 25  25  27 ... 151 152 149]]

# %%
import numpy as np

img2_array = np.array(img2)
print(img2_array.shape)
# Out:
# (256, 256)

# %%
print(img2_array)
# Out:
# [[162 162 162 ... 168 171 155]
#  [162 162 162 ... 168 171 155]
#  [162 162 162 ... 168 171 155]
#  ...
#  [ 48  57  54 ...  75  97  88]
#  [ 46  50  52 ...  89 100  98]
#  [ 44  55  54 ...  97 100 105]]
